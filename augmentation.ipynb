# %% [markdown]
# <a href="https://colab.research.google.com/github/zaman69/deep_learning_codes-_projects/blob/main/augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, BatchNormalization, Dropout

# %%
img = image.load_img('/content/dog.jpg',target_size=(200,200))
#This line loads an image file and resizes it to a specific size.

# %%
import matplotlib.pyplot as plt
plt.imshow(img)
#This line displays the loaded image using matplotlib.

# %%
datagen = ImageDataGenerator(
    rotation_range=50,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest',

)
# datagen is an object of ImageDataGenerator class, here,the objet is defined,meaning what type of change will be applied

# %%
img = image.img_to_array(img)

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
input_batch = img.reshape(1,200,200,3)

# %%
i=0;
for output in datagen.flow(input_batch,batch_size=1,save_to_dir='/content/different_image_dog'):
  i+=1;
  if i == 10:
    break;
